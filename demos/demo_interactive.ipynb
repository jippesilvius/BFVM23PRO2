# %%
from bokeh.io import output_file, show
from bokeh.io import output_notebook
from bokeh.plotting import figure, show


import pandas as pd
import numpy as np
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e23f1c56-fce9-4671-8ae1-3c7c83e6d5ff">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# We can make this plot interactive using panel. we need to reformat our print function to a callback function that returns a an output (a number, a table or a plot) based on input values. The input values come from the widget values. Widgets are radio buttons, drop down buttons, sliders and so on. First we make sure we can run the panel form the notebook by panel.extension()

# %%
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4b141f59-dec3-47f4-bd0f-0e63a1bac59f'>
#   <div id="f326d9a4-279d-4777-8f0b-4438fb939cfc" data-root-id="4b141f59-dec3-47f4-bd0f-0e63a1bac59f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
def render_print(x):
        return x*x

# %%
# we can create an interactive connection with interact, interacting between the output and input
interactive_panel = pn.interact(render_print, x=5)

# %%
interactive_panel
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=15, name='x', start=-5, value=5)
#     [1] Row
#         [0] Str(int, name='interactive00123')

# %%
interactive_panel[0] #widget
# Out:
# Column
#     [0] IntSlider(end=15, name='x', start=-5, value=5)

# %%
interactive_panel[1] #output
# Out:
# Row
#     [0] Str(int, name='interactive00123')

# %%
from bokeh.sampledata.iris import flowers

# %%
df = flowers
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from bokeh.models import ColumnDataSource
from bokeh.palettes import HighContrast3
from bokeh.transform import factor_cmap, factor_mark

def plot_df(x='sepal_length', y='sepal_width'):
    p = figure(title='iris flowers', y_axis_label=f'{y} (cm)', x_axis_label=f'{x} (cm)', toolbar_location=None)
    
    # Creating a ColumnDataSource from the DataFrame
    source = ColumnDataSource(df)
    
    species = sorted(df.species.unique())
    markers = ['hex', 'square', 'triangle']
    
    # Adding scatter plot with 'species' as hue and colormap
    p.scatter(x=x, 
              y=y, 
              source=source, 
              legend_field='species', 
              fill_alpha=0.6, 
              size=10, 
              color=factor_cmap('species', 'HighContrast3', species), 
              marker=factor_mark('species', markers, species))
    
    # Displaying the plot with legend
    p.legend.location = 'top_right'
    p.legend.title = 'Species'
    p.legend.click_policy = 'hide'
    
    show(p)


plot_df()
# Out:
#   <div id="bb4db7ac-6c14-4117-89b4-e693444eea17" data-root-id="98fb20bc-0b69-4dba-92ec-3ae1b4f1e4c4" style="display: contents;"></div>

# %%
columns = df.columns[:-1]
columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
##########################################################
# !!!!!!!!!! change plot with return p instead of show(p)
#########################################################

def render_plot(x='sepal_length', y='sepal_width'):
    p = figure(title='iris flowers', y_axis_label=f'{y} (cm)', x_axis_label=f'{x} (cm)', toolbar_location=None)
    
    # Creating a ColumnDataSource from the DataFrame
    source = ColumnDataSource(df)
    
    species = sorted(df.species.unique())
    markers = ['hex', 'square', 'triangle']
    
    # Adding scatter plot with 'species' as hue and colormap
    p.scatter(x=x, 
              y=y, 
              source=source, 
              fill_alpha=0.6, 
              size=10, 
              color=factor_cmap('species', 'HighContrast3', species), 
              marker=factor_mark('species', markers, species), 
              legend_field='species')
    
    # Displaying the plot with legend
    p.legend.location = 'top_right'
    p.legend.title = 'Species'

    
    return p

# %%
inter_plot = pn.interact(render_plot, x=columns, y=columns)
inter_plot
# Out:
# Column
#     [0] Column
#         [0] Select(name='x', options=['sepal_length', ...], value='sepal_length')
#         [1] Select(name='y', options=['sepal_length', ...], value='sepal_width')
#     [1] Row
#         [0] Bokeh(figure, name='interactive00160')

# %%
main_panel = pn.Row(
    pn.Column(inter_plot[1]),
    pn.Column(df.describe())
)

dashboard = pn.template.BootstrapTemplate(title='dashboard', sidebar_width=200)
dashboard.sidebar.append(inter_plot[0])
dashboard.main.append(main_panel)
dashboard.show()
# Out:
# Launching server at http://localhost:54302
