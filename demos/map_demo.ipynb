# %%
import folium
import pandas as pd
df = pd.read_csv('patients.csv')

# %%
df
# Out:
#                                          Id   BIRTHDATE   DEATHDATE  \
# 0      f0f3bc8d-ef38-49ce-a2bd-dfdda982b271  2017-08-24         NaN
# 1      067318a4-db8f-447f-8b6e-f2f61e9baaa5  2016-08-01         NaN
# 2      ae9efba3-ddc4-43f9-a781-f72019388548  1992-06-30         NaN
# 3      199c586f-af16-4091-9998-ee4cfc02ee7a  2004-01-09         NaN
# 4      353016ea-a0ff-4154-85bb-1cf8b6cedf20  1996-11-15         NaN
# ...                                     ...         ...         ...
# 12347  eec72396-d10e-4b8e-8fb6-25fc1e396031  1962-08-17         NaN
# 12348  3daf2b90-c439-469f-bb44-fb6109c6a8a7  1918-10-20  1999-11-01
# 12349  cb03d88e-7f08-46a1-be78-70d9fe8262a7  1918-10-20  2009-08-07
# 12350  435be43f-cb57-442f-aeb2-51018b030ed0  1918-10-20         NaN
# 12351  2712205f-755e-4897-acb3-926895b7d635  1941-02-11         NaN
#
#                SSN    DRIVERS    PASSPORT PREFIX        FIRST         LAST  \
# ...

# %%
import folium

# %%
# Make an empty map
"""
Building a map with Folium always start by initializing it. Pick the tile type
you want, and select the location and zoom you're interested in.
"""
m = folium.Map([20, -90], zoom_start=4)

# Show the map
m

# %%
"""
Let's loop through this data frame and add one bubble to each location. Adding one circle is made thanks to the Circle() function. It needs to be used together with the add_to() function to be added to the map you're working on.

Note that the radius parameter is set in meters. This is why it is multiplied by 20000 here, otherwise circles would be too small.

Last but not least, the popup parameters controls what's available in the popup you get when you click on a circle.
"""

# add marker one by one on the map
for i in range(0,len(df)):
   folium.Circle(
      location=[df.iloc[i]['LAT'], df.iloc[i]['LON']],
      popup=df.iloc[i]['HEALTHCARE_EXPENSES'],
      radius=float(df.iloc[i]['HEALTHCARE_EXPENSES']),
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)

# Show the map again
m

# %%
massachusetts: 'https://raw.githubusercontent.com/glynnbird/usstatesgeojson/master/massachusetts.geojson'
#massachusetts_geo = config['massachusetts']


mapobj = folium.Map(location= [41, -70], zoom_start=7)

borderstyle = {
    'color': 'black',
    'fill': False,
    'weight': 2
}

folium.GeoJson(data=massachusetts_geo, name='borders', style_function=lambda x: borderstyle).add_to(mapobj)
data_points = folium.FeatureGroup('healthcost').add_to(mapobj)

for i in range(0, len(df_patients)):
    # sets the color to green if the person is still alive
    if pd.isnull(df_patients.iloc[i]['DEATHDATE']):
        color = 'green'
    else:
        color = 'red'
    # obtain coords
    lat = df_patients.iloc[i]['LAT']
    lon = df_patients.iloc[i]['LON']
    folium.Circle(location=[lat, lon], color=color).add_to(data_points)  # create datapoint
    
folium.LayerControl().add_to(mapobj)
mapobj
